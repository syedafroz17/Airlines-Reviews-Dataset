# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# #1. British Airways

# %%
def scrape_page(page_number):
    url = f'https://www.airlinequality.com/airline-reviews/british-airways/page/{page_number}/'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    reviews = []
    for review_div in soup.find_all('div', class_='body'):
        name_tag = review_div.find('span', itemprop='name')
        location_tag = review_div.find('h3', class_='text_sub_header')
        date_tag = review_div.find('time', itemprop='datePublished')
        text_content_div = review_div.find('div', class_='text_content')

        # Extract review details with error handling
        name = name_tag.text if name_tag else 'N/A'
        location = location_tag.text.split(' ')[-1] if location_tag else 'N/A'
        date_published = date_tag['datetime'] if date_tag else 'N/A'
        text_content = text_content_div.text.strip() if text_content_div else 'N/A'

        # Extract ratings
        review_stats = review_div.find('div', class_='review-stats')
        rating_elements = review_stats.find_all('tr') if review_stats else []

        seat_type = rating_elements[0].find_all('td')[1].text.strip() if len(rating_elements) > 0 else 'N/A'
        seat_comfort = extract_rating(rating_elements[1].find('td', class_='review-rating-stars')) if len(rating_elements) > 1 else 'N/A'
        cabin_staff_service = extract_rating(rating_elements[2].find('td', class_='review-rating-stars')) if len(rating_elements) > 2 else 'N/A'
        food_beverages = extract_rating(rating_elements[3].find('td', class_='review-rating-stars')) if len(rating_elements) > 3 else 'N/A'
        inflight_entertainment = extract_rating(rating_elements[4].find('td', class_='review-rating-stars')) if len(rating_elements) > 4 else 'N/A'
        value_for_money = extract_rating(rating_elements[5].find('td', class_='review-rating-stars')) if len(rating_elements) > 5 else 'N/A'
        recommended_text = rating_elements[6].find_all('td')[1].text.strip() if len(rating_elements) > 6 else 'N/A'
        recommended = recommended_text.lower() == 'yes' if recommended_text != 'N/A' else None

        # Append extracted data to the list
        reviews.append({
            'Name': name,
            'Location': location,
            'Date Published': date_published,
            'Text Content': text_content,
            'Seat Type': seat_type,
            'Seat Comfort': seat_comfort,
            'Cabin Staff Service': cabin_staff_service,
            'Food & Beverages': food_beverages,
            'Inflight Entertainment': inflight_entertainment,
            'Value For Money': value_for_money,
            'Recommended': recommended
        })

    return reviews

# %%
def extract_rating(star_elements):
    if star_elements:
        filled_stars = star_elements.find_all('span', class_='star fill')
        return len(filled_stars)
    return None

# %%
# Main loop to scrape multiple pages and track progress
british_airways_reviews = []
total_pages = 385
for page_number in range(1, total_pages + 1):
    page_reviews = scrape_page(page_number)
    british_airways_reviews.extend(page_reviews)

    # Print progress message
    if page_number % 10 == 0:
        print(f"{page_number} pages extraction completed")
# Out:
# 10 pages extraction completed
# 20 pages extraction completed
# 30 pages extraction completed
# 40 pages extraction completed
# 50 pages extraction completed
# 60 pages extraction completed
# 70 pages extraction completed
# 80 pages extraction completed
# 90 pages extraction completed
# 100 pages extraction completed
# 110 pages extraction completed
# 120 pages extraction completed
# 130 pages extraction completed
# 140 pages extraction completed
# 150 pages extraction completed
# 160 pages extraction completed
# 170 pages extraction completed
# 180 pages extraction completed
# 190 pages extraction completed
# 200 pages extraction completed
# 210 pages extraction completed
# 220 pages extraction completed
# 230 pages extraction completed
# 240 pages extraction completed
# 250 pages extraction completed
# 260 pages extraction completed
# 270 pages extraction completed
# 280 pages extraction completed
# 290 pages extraction completed
# 300 pages extraction completed
# 310 pages extraction completed
# 320 pages extraction completed
# 330 pages extraction completed
# 340 pages extraction completed
# 350 pages extraction completed
# 360 pages extraction completed
# 370 pages extraction completed
# 380 pages extraction completed

# %%
british_airways_reviews_df = pd.DataFrame(british_airways_reviews)

# %%
british_airways_reviews_df.sample(5)
# Out:
#                Name Location Date Published  \
# 1091         D Gold     2019     2019-02-26
# 2058      P Greeson     2016     2016-12-22
# 2326       Jim Zaza     2016     2016-07-13
# 873   Luis Casasola     2019     2019-10-13
# 2419     S Williams     2016     2016-05-14
#
#                                            Text Content  \
# 1091  ✅ Trip Verified |  Chicago to London Heathrow....
# 2058  ✅ Verified Review |  Baltimore Washington to L...
# 2326  ✅ Verified Review |  London Heathrow to Boston...
# 873   ✅ Trip Verified | Mexico City to Barcelona via...
# 2419  ✅ Verified Review |  British Airways have seri...
#
#                    Seat Type  Seat Comfort  Cabin Staff Service  \
# 1091                B747-400           NaN                  NaN
# 2058              Boeing 787           NaN                  NaN
# 2326              Boeing 777           NaN                  NaN
# 873   Boeing 787-9, A320-200           NaN                  NaN
# 2419          Couple Leisure           NaN                  NaN
#
#      Food & Beverages Inflight Entertainment Value For Money Recommended
# 1091             None                   None               1       False
# 2058             None                   None               2       False
# 2326             None                   None               4       False
# 873              None                   None               5       False
# 2419             None                      3               2       False

# %%
british_airways_reviews_df.shape
# Out:
# (3841, 11)

# %%
british_airways_reviews_df.to_csv('british_airways_reviews.csv', index=False)

# %% [markdown]
# #2. Air France

# %%
def scrape_page(page_number):
    url = f'https://www.airlinequality.com/airline-reviews/air-france/page/{page_number}/'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    reviews = []
    for review_div in soup.find_all('div', class_='body'):
        name_tag = review_div.find('span', itemprop='name')
        location_tag = review_div.find('h3', class_='text_sub_header')
        date_tag = review_div.find('time', itemprop='datePublished')
        text_content_div = review_div.find('div', class_='text_content')

        # Extract review details with error handling
        name = name_tag.text if name_tag else 'N/A'
        location = location_tag.text.split(' ')[-1] if location_tag else 'N/A'
        date_published = date_tag['datetime'] if date_tag else 'N/A'
        text_content = text_content_div.text.strip() if text_content_div else 'N/A'

        # Extract ratings
        review_stats = review_div.find('div', class_='review-stats')
        rating_elements = review_stats.find_all('tr') if review_stats else []

        seat_type = rating_elements[0].find_all('td')[1].text.strip() if len(rating_elements) > 0 else 'N/A'
        seat_comfort = extract_rating(rating_elements[1].find('td', class_='review-rating-stars')) if len(rating_elements) > 1 else 'N/A'
        cabin_staff_service = extract_rating(rating_elements[2].find('td', class_='review-rating-stars')) if len(rating_elements) > 2 else 'N/A'
        food_beverages = extract_rating(rating_elements[3].find('td', class_='review-rating-stars')) if len(rating_elements) > 3 else 'N/A'
        inflight_entertainment = extract_rating(rating_elements[4].find('td', class_='review-rating-stars')) if len(rating_elements) > 4 else 'N/A'
        ground_service = extract_rating(rating_elements[5].find('td', class_='review-rating-stars')) if len(rating_elements) > 5 else 'N/A'
        wifi_connectivity = extract_rating(rating_elements[6].find('td', class_='review-rating-stars')) if len(rating_elements) > 6 else 'N/A'
        value_for_money = extract_rating(rating_elements[7].find('td', class_='review-rating-stars')) if len(rating_elements) > 7 else 'N/A'
        recommended_text = rating_elements[8].find_all('td')[1].text.strip() if len(rating_elements) > 8 else 'N/A'
        recommended = recommended_text.lower() == 'yes' if recommended_text != 'N/A' else None

        # Append extracted data to the list
        reviews.append({
            'Name': name,
            'Location': location,
            'Date Published': date_published,
            'Text Content': text_content,
            'Seat Type': seat_type,
            'Seat Comfort': seat_comfort,
            'Cabin Staff Service': cabin_staff_service,
            'Food & Beverages': food_beverages,
            'Inflight Entertainment': inflight_entertainment,
            'Ground Service': ground_service,
            'Wifi & Connectivity': wifi_connectivity,
            'Value For Money': value_for_money,
            'Recommended': recommended
        })

    return reviews

# %%
air_france_reviews = []
total_pages = 138
for page_number in range(1, total_pages + 1):
    page_reviews = scrape_page(page_number)
    air_france_reviews.extend(page_reviews)

    # Print progress message
    if page_number % 10 == 0:
        print(f"{page_number} pages extraction completed")
# Out:
# 10 pages extraction completed
# 20 pages extraction completed
# 30 pages extraction completed
# 40 pages extraction completed
# 50 pages extraction completed
# 60 pages extraction completed
# 70 pages extraction completed
# 80 pages extraction completed
# 90 pages extraction completed
# 100 pages extraction completed
# 110 pages extraction completed
# 120 pages extraction completed
# 130 pages extraction completed

# %%
air_framce_reviews_df = pd.DataFrame(air_france_reviews)

# %%
air_framce_reviews_df.sample(5)
# Out:
#                  Name Location Date Published  \
# 641  Guillaume Miceli     2017     2017-12-28
# 511          P Walena     2018     2018-11-21
# 214            D Lane     2022     2022-07-21
# 627    Ricardo Feliu      2018     2018-02-15
# 21           S Tavani     2024     2024-05-29
#
#                                           Text Content  \
# 641  ✅ Trip Verified | I flew from London to Paris ...
# 511  ✅ Trip Verified |  Krakow to Amsterdam via Par...
# 214  ✅ Trip Verified |  Moved my flight forward 24 ...
# 627  ✅ Trip Verified | January 30, 2018, flight AF1...
# 21   ✅ Trip Verified |  Air France weighs cabin lug...
#
#                         Seat Type  Seat Comfort  Cabin Staff Service  \
# 641                    Boeing 787           NaN                  NaN
# 511  Boeing 737-800 / Embraer 190           NaN                  NaN
# 214                Boeing 777-300           NaN                  NaN
# 627                Family Leisure           NaN                  NaN
# 21                   Solo Leisure           NaN                  NaN
#
#      Food & Beverages  Inflight Entertainment Ground Service  \
# 641               NaN                     NaN              5
# 511               NaN                     NaN              5
# 214               NaN                     NaN              1
# 627               NaN                     1.0              1
# 21                NaN                     3.0              2
#
#     Wifi & Connectivity Value For Money Recommended
# 641                   4               5       False
# 511                   5               5       False
# 214                   1               1       False
# 627                   3               3       False
# 21                    3               1       False

# %%
air_framce_reviews_df.shape
# Out:
# (1378, 13)

# %%
air_framce_reviews_df.to_csv('air_france_reviews.csv', index=False)

# %% [markdown]
# #3. Qatar Airways

# %%
def scrape_page(page_number):
    url = f'https://www.airlinequality.com/airline-reviews/qatar-airways/page/{page_number}/'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    reviews = []
    for review_div in soup.find_all('div', class_='body'):
        name_tag = review_div.find('span', itemprop='name')
        location_tag = review_div.find('h3', class_='text_sub_header')
        date_tag = review_div.find('time', itemprop='datePublished')
        text_content_div = review_div.find('div', class_='text_content')

        # Extract review details with error handling
        name = name_tag.text if name_tag else 'N/A'
        location = location_tag.text.split(' ')[-1] if location_tag else 'N/A'
        date_published = date_tag['datetime'] if date_tag else 'N/A'
        text_content = text_content_div.text.strip() if text_content_div else 'N/A'

        # Extract ratings
        review_stats = review_div.find('div', class_='review-stats')
        rating_elements = review_stats.find_all('tr') if review_stats else []

        seat_type = rating_elements[0].find_all('td')[1].text.strip() if len(rating_elements) > 0 else 'N/A'
        seat_comfort = extract_rating(rating_elements[1].find('td', class_='review-rating-stars')) if len(rating_elements) > 1 else 'N/A'
        cabin_staff_service = extract_rating(rating_elements[2].find('td', class_='review-rating-stars')) if len(rating_elements) > 2 else 'N/A'
        food_beverages = extract_rating(rating_elements[3].find('td', class_='review-rating-stars')) if len(rating_elements) > 3 else 'N/A'
        inflight_entertainment = extract_rating(rating_elements[4].find('td', class_='review-rating-stars')) if len(rating_elements) > 4 else 'N/A'
        ground_service = extract_rating(rating_elements[5].find('td', class_='review-rating-stars')) if len(rating_elements) > 5 else 'N/A'
        wifi_connectivity = extract_rating(rating_elements[6].find('td', class_='review-rating-stars')) if len(rating_elements) > 6 else 'N/A'
        value_for_money = extract_rating(rating_elements[7].find('td', class_='review-rating-stars')) if len(rating_elements) > 7 else 'N/A'
        recommended_text = rating_elements[8].find_all('td')[1].text.strip() if len(rating_elements) > 8 else 'N/A'
        recommended = recommended_text.lower() == 'yes' if recommended_text != 'N/A' else None

        # Append extracted data to the list
        reviews.append({
            'Name': name,
            'Location': location,
            'Date Published': date_published,
            'Text Content': text_content,
            'Seat Type': seat_type,
            'Seat Comfort': seat_comfort,
            'Cabin Staff Service': cabin_staff_service,
            'Food & Beverages': food_beverages,
            'Inflight Entertainment': inflight_entertainment,
            'Ground Service': ground_service,
            'Wifi & Connectivity': wifi_connectivity,
            'Value For Money': value_for_money,
            'Recommended': recommended
        })

    return reviews

# %%
qatar_airways_reviews = []
total_pages = 247
for page_number in range(1, total_pages + 1):
    page_reviews = scrape_page(page_number)
    qatar_airways_reviews.extend(page_reviews)

    # Print progress message
    if page_number % 10 == 0:
        print(f"{page_number} pages extraction completed")
# Out:
# 10 pages extraction completed
# 20 pages extraction completed
# 30 pages extraction completed
# 40 pages extraction completed
# 50 pages extraction completed
# 60 pages extraction completed
# 70 pages extraction completed
# 80 pages extraction completed
# 90 pages extraction completed
# 100 pages extraction completed
# 110 pages extraction completed
# 120 pages extraction completed
# 130 pages extraction completed
# 140 pages extraction completed
# 150 pages extraction completed
# 160 pages extraction completed
# 170 pages extraction completed
# 180 pages extraction completed
# 190 pages extraction completed
# 200 pages extraction completed
# 210 pages extraction completed
# 220 pages extraction completed
# 230 pages extraction completed
# 240 pages extraction completed

# %%
qatar_airways_reviews_df = pd.DataFrame(qatar_airways_reviews)

# %%
qatar_airways_reviews_df.sample(5)
# Out:
#                 Name Location Date Published  \
# 979   Rajan Parrikar     2019     2019-08-03
# 575    Winsome Peter     2022     2022-02-19
# 1623           M Tan     2016     2016-10-23
# 121         A Qarani     2024     2024-01-14
# 2030    J Scholfield     2015     2015-06-13
#
#                                            Text Content         Seat Type  \
# 979   ✅ Trip Verified |  Mumbai to Copenhagen via Do...  Boeing 777-300ER
# 575   ✅ Trip Verified |  My congratulations to the Q...      Solo Leisure
# 1623  ✅ Verified Review |  Singapore to Kilimanjaro ...          Business
# 121   ✅ Trip Verified |  Following a downgrade of my...          Business
# 2030  Flew LHR to AUH via DOH return. Outbound on th...               787
#
#       Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 979            NaN                  NaN               NaN
# 575            NaN                  NaN               NaN
# 1623           NaN                  NaN               NaN
# 121            NaN                  NaN               NaN
# 2030           NaN                  NaN               NaN
#
#       Inflight Entertainment  Ground Service Wifi & Connectivity  \
# 979                      NaN             5.0                   5
# 575                      5.0             5.0                   5
# 1623                     4.0             4.0                   4
# 121                      1.0             3.0                   2
# 2030                     3.0             4.0                   4
#
#      Value For Money Recommended
# 979                5       False
# 575                5       False
# 1623               2       False
# 121                1       False
# 2030               4       False

# %%
qatar_airways_reviews_df.shape
# Out:
# (2470, 13)

# %%
qatar_airways_reviews_df.to_csv('qatar_airways_reviews.csv', index=False)

# %% [markdown]
# #4. Qantas-Airways

# %%
def scrape_page(page_number):
    url = f'https://www.airlinequality.com/airline-reviews/qantas-airways/page/{page_number}/'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    reviews = []
    for review_div in soup.find_all('div', class_='body'):
        name_tag = review_div.find('span', itemprop='name')
        location_tag = review_div.find('h3', class_='text_sub_header')
        date_tag = review_div.find('time', itemprop='datePublished')
        text_content_div = review_div.find('div', class_='text_content')

        # Extract review details with error handling
        name = name_tag.text if name_tag else 'N/A'
        location = location_tag.text.split(' ')[-1] if location_tag else 'N/A'
        date_published = date_tag['datetime'] if date_tag else 'N/A'
        text_content = text_content_div.text.strip() if text_content_div else 'N/A'

        # Extract ratings
        review_stats = review_div.find('div', class_='review-stats')
        rating_elements = review_stats.find_all('tr') if review_stats else []

        seat_type = rating_elements[0].find_all('td')[1].text.strip() if len(rating_elements) > 0 else 'N/A'
        seat_comfort = extract_rating(rating_elements[1].find('td', class_='review-rating-stars')) if len(rating_elements) > 1 else 'N/A'
        cabin_staff_service = extract_rating(rating_elements[2].find('td', class_='review-rating-stars')) if len(rating_elements) > 2 else 'N/A'
        food_beverages = extract_rating(rating_elements[3].find('td', class_='review-rating-stars')) if len(rating_elements) > 3 else 'N/A'
        inflight_entertainment = extract_rating(rating_elements[4].find('td', class_='review-rating-stars')) if len(rating_elements) > 4 else 'N/A'
        ground_service = extract_rating(rating_elements[5].find('td', class_='review-rating-stars')) if len(rating_elements) > 5 else 'N/A'
        wifi_connectivity = extract_rating(rating_elements[6].find('td', class_='review-rating-stars')) if len(rating_elements) > 6 else 'N/A'
        value_for_money = extract_rating(rating_elements[7].find('td', class_='review-rating-stars')) if len(rating_elements) > 7 else 'N/A'
        recommended_text = rating_elements[8].find_all('td')[1].text.strip() if len(rating_elements) > 8 else 'N/A'
        recommended = recommended_text.lower() == 'yes' if recommended_text != 'N/A' else None

        # Append extracted data to the list
        reviews.append({
            'Name': name,
            'Location': location,
            'Date Published': date_published,
            'Text Content': text_content,
            'Seat Type': seat_type,
            'Seat Comfort': seat_comfort,
            'Cabin Staff Service': cabin_staff_service,
            'Food & Beverages': food_beverages,
            'Inflight Entertainment': inflight_entertainment,
            'Ground Service': ground_service,
            'Wifi & Connectivity': wifi_connectivity,
            'Value For Money': value_for_money,
            'Recommended': recommended
        })

    return reviews

# %%
qantas_airways_reviews = []
total_pages = 192
for page_number in range(1, total_pages + 1):
    page_reviews = scrape_page(page_number)
    qantas_airways_reviews.extend(page_reviews)

    # Print progress message
    if page_number % 10 == 0:
        print(f"{page_number} pages extraction completed")
# Out:
# 10 pages extraction completed
# 20 pages extraction completed
# 30 pages extraction completed
# 40 pages extraction completed
# 50 pages extraction completed
# 60 pages extraction completed
# 70 pages extraction completed
# 80 pages extraction completed
# 90 pages extraction completed
# 100 pages extraction completed
# 110 pages extraction completed
# 120 pages extraction completed
# 130 pages extraction completed
# 140 pages extraction completed
# 150 pages extraction completed
# 160 pages extraction completed
# 170 pages extraction completed
# 180 pages extraction completed
# 190 pages extraction completed

# %%
qantas_airways_reviews_df = pd.DataFrame(qantas_airways_reviews)

# %%
qantas_airways_reviews_df.sample(5)
# Out:
#             Name Location Date Published  \
# 789     F Irving     2018     2018-03-29
# 880     D Peters     2017     2017-10-28
# 427   C Thompson     2020     2020-01-21
# 1684  Jay Howard     2014     2014-04-27
# 1016     J Singh     2017     2017-01-14
#
#                                            Text Content       Seat Type  \
# 789   ✅ Trip Verified | QF2 flight from Dubai to Syd...            A380
# 880   ✅ Verified Review |  QF971, October 26, Townsv...    Solo Leisure
# 427   ✅ Trip Verified | Perth to Cairns via Brisbane...      Boeing 737
# 1684  BKK-SYD. Off to a bad start when they tried to...  Business Class
# 1016  ✅ Verified Review |  Melbourne to Dubai with Q...            A380
#
#       Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 789            NaN                  NaN               NaN
# 880            NaN                  NaN               NaN
# 427            NaN                  NaN               NaN
# 1684           3.0                  3.0               1.0
# 1016           NaN                  NaN               NaN
#
#      Inflight Entertainment Ground Service Wifi & Connectivity  \
# 789                    None              1                   1
# 880                       5              5                   5
# 427                    None              2                   1
# 1684                      4              3                None
# 1016                   None              3                   2
#
#      Value For Money Recommended
# 789                1       False
# 880                5       False
# 427                3       False
# 1684             N/A        None
# 1016               2       False

# %%
qantas_airways_reviews_df.shape
# Out:
# (1916, 13)

# %%
qantas_airways_reviews_df.to_csv('qantas_airways_reviews.csv', index=False)

# %% [markdown]
# #5.Singapore Airlines

# %%
def scrape_page(page_number):
    url = f'https://www.airlinequality.com/airline-reviews/singapore-airlines/page/{page_number}/'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    reviews = []
    for review_div in soup.find_all('div', class_='body'):
        name_tag = review_div.find('span', itemprop='name')
        location_tag = review_div.find('h3', class_='text_sub_header')
        date_tag = review_div.find('time', itemprop='datePublished')
        text_content_div = review_div.find('div', class_='text_content')

        # Extract review details with error handling
        name = name_tag.text if name_tag else 'N/A'
        location = location_tag.text.split(' ')[-1] if location_tag else 'N/A'
        date_published = date_tag['datetime'] if date_tag else 'N/A'
        text_content = text_content_div.text.strip() if text_content_div else 'N/A'

        # Extract ratings
        review_stats = review_div.find('div', class_='review-stats')
        rating_elements = review_stats.find_all('tr') if review_stats else []

        seat_type = rating_elements[0].find_all('td')[1].text.strip() if len(rating_elements) > 0 else 'N/A'
        seat_comfort = extract_rating(rating_elements[1].find('td', class_='review-rating-stars')) if len(rating_elements) > 1 else 'N/A'
        cabin_staff_service = extract_rating(rating_elements[2].find('td', class_='review-rating-stars')) if len(rating_elements) > 2 else 'N/A'
        food_beverages = extract_rating(rating_elements[3].find('td', class_='review-rating-stars')) if len(rating_elements) > 3 else 'N/A'
        inflight_entertainment = extract_rating(rating_elements[4].find('td', class_='review-rating-stars')) if len(rating_elements) > 4 else 'N/A'
        ground_service = extract_rating(rating_elements[5].find('td', class_='review-rating-stars')) if len(rating_elements) > 5 else 'N/A'
        wifi_connectivity = extract_rating(rating_elements[6].find('td', class_='review-rating-stars')) if len(rating_elements) > 6 else 'N/A'
        value_for_money = extract_rating(rating_elements[7].find('td', class_='review-rating-stars')) if len(rating_elements) > 7 else 'N/A'
        recommended_text = rating_elements[8].find_all('td')[1].text.strip() if len(rating_elements) > 8 else 'N/A'
        recommended = recommended_text.lower() == 'yes' if recommended_text != 'N/A' else None

        # Append extracted data to the list
        reviews.append({
            'Name': name,
            'Location': location,
            'Date Published': date_published,
            'Text Content': text_content,
            'Seat Type': seat_type,
            'Seat Comfort': seat_comfort,
            'Cabin Staff Service': cabin_staff_service,
            'Food & Beverages': food_beverages,
            'Inflight Entertainment': inflight_entertainment,
            'Ground Service': ground_service,
            'Wifi & Connectivity': wifi_connectivity,
            'Value For Money': value_for_money,
            'Recommended': recommended
        })

    return reviews

# %%
singapore_airlines_reviews = []
total_pages = 160
for page_number in range(1, total_pages + 1):
    page_reviews = scrape_page(page_number)
    singapore_airlines_reviews.extend(page_reviews)

    # Print progress message
    if page_number % 10 == 0:
        print(f"{page_number} pages extraction completed")
# Out:
# 10 pages extraction completed
# 20 pages extraction completed
# 30 pages extraction completed
# 40 pages extraction completed
# 50 pages extraction completed
# 60 pages extraction completed
# 70 pages extraction completed
# 80 pages extraction completed
# 90 pages extraction completed
# 100 pages extraction completed
# 110 pages extraction completed
# 120 pages extraction completed
# 130 pages extraction completed
# 140 pages extraction completed
# 150 pages extraction completed
# 160 pages extraction completed

# %%
singapore_airlines_reviews_df = pd.DataFrame(singapore_airlines_reviews)

# %%
singapore_airlines_reviews_df.sample(5)
# Out:
#             Name Location Date Published  \
# 428   Elaine Loh     2019     2019-11-06
# 118   Lukas Fajt     2023     2023-08-29
# 405       L Tran     2019     2019-12-02
# 396  R Margathan     2019     2019-12-20
# 297      V Ellis     2022     2022-03-20
#
#                                           Text Content       Seat Type  \
# 428  ✅ Trip Verified |  Perth to Singapore. A pleas...    Solo Leisure
# 118  Not Verified |  We flew with Singapore to New ...            A380
# 405  ✅ Trip Verified |  Singapore to Tokyo. I chose...        A380-800
# 396  ✅ Trip Verified |  Would like to shout out a s...  Family Leisure
# 297  Not Verified |  A350 from Melbourne to Singapo...     A350 / A380
#
#      Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 428           NaN                  NaN               NaN
# 118           NaN                  NaN               NaN
# 405           NaN                  NaN               NaN
# 396           NaN                  NaN               NaN
# 297           NaN                  NaN               NaN
#
#      Inflight Entertainment Ground Service Wifi & Connectivity  \
# 428                     4.0              5                   4
# 118                     NaN              5                   5
# 405                     NaN              5                   5
# 396                     5.0              5                   4
# 297                     NaN              2                   3
#
#     Value For Money Recommended
# 428               4       False
# 118               5       False
# 405               4       False
# 396               5       False
# 297               2       False

# %%
singapore_airlines_reviews_df.shape
# Out:
# (1598, 13)

# %%
singapore_airlines_reviews_df.to_csv('singapore_airlines_reviews.csv', index=False)

# %% [markdown]
# #6. Emirates

# %%
def scrape_page(page_number):
    url = f'https://www.airlinequality.com/airline-reviews/emirates/page/{page_number}/'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    reviews = []
    for review_div in soup.find_all('div', class_='body'):
        name_tag = review_div.find('span', itemprop='name')
        location_tag = review_div.find('h3', class_='text_sub_header')
        date_tag = review_div.find('time', itemprop='datePublished')
        text_content_div = review_div.find('div', class_='text_content')

        # Extract review details with error handling
        name = name_tag.text if name_tag else 'N/A'
        location = location_tag.text.split(' ')[-1] if location_tag else 'N/A'
        date_published = date_tag['datetime'] if date_tag else 'N/A'
        text_content = text_content_div.text.strip() if text_content_div else 'N/A'

        # Extract ratings
        review_stats = review_div.find('div', class_='review-stats')
        rating_elements = review_stats.find_all('tr') if review_stats else []

        seat_type = rating_elements[0].find_all('td')[1].text.strip() if len(rating_elements) > 0 else 'N/A'
        seat_comfort = extract_rating(rating_elements[1].find('td', class_='review-rating-stars')) if len(rating_elements) > 1 else 'N/A'
        cabin_staff_service = extract_rating(rating_elements[2].find('td', class_='review-rating-stars')) if len(rating_elements) > 2 else 'N/A'
        food_beverages = extract_rating(rating_elements[3].find('td', class_='review-rating-stars')) if len(rating_elements) > 3 else 'N/A'
        inflight_entertainment = extract_rating(rating_elements[4].find('td', class_='review-rating-stars')) if len(rating_elements) > 4 else 'N/A'
        ground_service = extract_rating(rating_elements[5].find('td', class_='review-rating-stars')) if len(rating_elements) > 5 else 'N/A'
        wifi_connectivity = extract_rating(rating_elements[6].find('td', class_='review-rating-stars')) if len(rating_elements) > 6 else 'N/A'
        value_for_money = extract_rating(rating_elements[7].find('td', class_='review-rating-stars')) if len(rating_elements) > 7 else 'N/A'
        recommended_text = rating_elements[8].find_all('td')[1].text.strip() if len(rating_elements) > 8 else 'N/A'
        recommended = recommended_text.lower() == 'yes' if recommended_text != 'N/A' else None

        # Append extracted data to the list
        reviews.append({
            'Name': name,
            'Location': location,
            'Date Published': date_published,
            'Text Content': text_content,
            'Seat Type': seat_type,
            'Seat Comfort': seat_comfort,
            'Cabin Staff Service': cabin_staff_service,
            'Food & Beverages': food_beverages,
            'Inflight Entertainment': inflight_entertainment,
            'Ground Service': ground_service,
            'Wifi & Connectivity': wifi_connectivity,
            'Value For Money': value_for_money,
            'Recommended': recommended
        })

    return reviews

# %%
emirates_reviews = []
total_pages = 239
for page_number in range(1, total_pages + 1):
    page_reviews = scrape_page(page_number)
    emirates_reviews.extend(page_reviews)

    # Print progress message
    if page_number % 10 == 0:
        print(f"{page_number} pages extraction completed")
# Out:
# 10 pages extraction completed
# 20 pages extraction completed
# 30 pages extraction completed
# 40 pages extraction completed
# 50 pages extraction completed
# 60 pages extraction completed
# 70 pages extraction completed
# 80 pages extraction completed
# 90 pages extraction completed
# 100 pages extraction completed
# 110 pages extraction completed
# 120 pages extraction completed
# 130 pages extraction completed
# 140 pages extraction completed
# 150 pages extraction completed
# 160 pages extraction completed
# 170 pages extraction completed
# 180 pages extraction completed
# 190 pages extraction completed
# 200 pages extraction completed
# 210 pages extraction completed
# 220 pages extraction completed
# 230 pages extraction completed

# %%
emirates_reviews_df = pd.DataFrame(emirates_reviews)

# %%
emirates_reviews_df.sample(5)
# Out:
#                    Name Location Date Published  \
# 1342       Bojan Tercon     2016     2016-08-14
# 1453  Marcin Gorczyński     2016     2016-03-13
# 1109       John Curtain     2017     2017-06-27
# 2004        Ian Solomon     2014     2014-10-08
# 545        Badr Darwish     2019     2019-08-22
#
#                                            Text Content       Seat Type  \
# 1342  ✅ Verified Review |  To me, Emirates A380 has ...            A380
# 1453  Dubai to Warsaw with Emirates. My seats, selec...      Boeing 777
# 1109  ✅ Verified Review |  Athens to Dubai. I enjoye...      Boeing 777
# 2004  Having flown First or Business class long-haul...     First Class
# 545   ✅ Trip Verified |  \r\nDubai to Tunis. Flight ...  Couple Leisure
#
#       Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 1342           NaN                  NaN               NaN
# 1453           NaN                  NaN               NaN
# 1109           NaN                  NaN               NaN
# 2004           4.0                  2.0               5.0
# 545            NaN                  NaN               NaN
#
#       Inflight Entertainment  Ground Service Wifi & Connectivity  \
# 1342                     NaN             5.0                   3
# 1453                     NaN             1.0                   1
# 1109                     NaN             3.0                   4
# 2004                     5.0             1.0                None
# 545                      1.0             3.0                   3
#
#      Value For Money Recommended
# 1342               2       False
# 1453               4       False
# 1109               4       False
# 2004             N/A        None
# 545                2       False

# %%
emirates_reviews_df.shape
# Out:
# (2387, 13)

# %%
emirates_reviews_df.to_csv('emirates_reviews.csv', index=False)

# %%
int(british_airways_reviews_df.shape[0]) + \
int(air_framce_reviews_df.shape[0]) + \
int(qatar_airways_reviews_df.shape[0]) + \
int(qantas_airways_reviews_df.shape[0])+ \
int(singapore_airlines_reviews_df.shape[0])+int(emirates_reviews_df.shape[0])
# Out:
# 13590

# %%
british_airways_reviews_df['Airlines']='british_airways'

# %%
british_airways_reviews_df.sample(5)
# Out:
#                  Name Location Date Published  \
# 1509  Raymond Grayson     2017     2017-11-30
# 2658     Patrick Beet     2015     2015-12-10
# 945     Dave Matthews     2019     2019-08-09
# 2463   Alistair Baker     2016     2016-04-12
# 1364     Helen Santry     2018     2018-04-29
#
#                                            Text Content       Seat Type  \
# 1509  ✅ Trip Verified | Flew Newcastle to San Franci...  Couple Leisure
# 2658  Flew British Airways back from Bangkok to Lond...      Boeing 777
# 945   Not Verified |  British Airways flight to Brus...  Couple Leisure
# 2463  ✅ Verified Review |  I decided to treat myself...  Boeing 747-400
# 1364  ✅ Trip Verified |  London Heathrow to Vancouve...      Boeing 747
#
#       Seat Comfort  Cabin Staff Service Food & Beverages  \
# 1509           NaN                  NaN             None
# 2658           NaN                  NaN             None
# 945            NaN                  NaN             None
# 2463           NaN                  NaN             None
# 1364           NaN                  NaN             None
#
#      Inflight Entertainment Value For Money Recommended
# 1509                      4               5       False
# 2658                   None               5       False
# 945                       2               4       False
# 2463                   None               5       False
# 1364                   None               1       False

# %%
british_airways_reviews_df.insert(0, 'Airlines', 'british_airways')

# %%
british_airways_reviews_df
# Out:
#              Airlines           Name Location Date Published  \
# 0     british_airways        C Hayne     2024     2024-08-15
# 1     british_airways      C Porter      2024     2024-08-12
# 2     british_airways        G Jones     2024     2024-08-12
# 3     british_airways    Edward King     2024     2024-08-11
# 4     british_airways         N Kwok     2024     2024-08-09
# ...               ...            ...      ...            ...
# 3836  british_airways    C Mcculloch     2012     2012-08-29
# 3837  british_airways     Nick Berry     2012     2012-08-28
# 3838  british_airways  Avril Barclay     2011     2011-10-12
# 3839  british_airways         C Volz     2011     2011-10-11
# 3840  british_airways      Russ King     2011     2011-10-09
#
#                                            Text Content        Seat Type  \
# 0     Not Verified | Before my flight, I was forced ...     Solo Leisure
# 1     ✅ Trip Verified |   British Airways at its bes...             A350
# 2     ✅ Trip Verified | An excellent flight! Despite...             A320
# 3     ✅ Trip Verified | I recently traveled with Bri...             A380
# 4     ✅ Trip Verified |   My family and I were booke...   Family Leisure
# ...                                                 ...              ...
# 3836  Flight from Heathrow to Toronto. Booked emerge...    Economy Class
# 3837  LHR to HAM. Purser addresses all club passenge...   Business Class
# 3838  My son who had worked for British Airways urge...    Economy Class
# 3839  London City-New York JFK via Shannon on A318 b...  Premium Economy
# 3840  SIN-LHR BA12 B747-436 First Class. Old aircraf...      First Class
#
#       Seat Comfort  Cabin Staff Service Food & Beverages  \
# 0              NaN                  NaN             None
# 1              NaN                  NaN             None
# 2              NaN                  NaN             None
# 3              NaN                  NaN             None
# 4              NaN                  NaN             None
# ...            ...                  ...              ...
# 3836           3.0                  3.0                3
# 3837           4.0                  5.0                4
# 3838           4.0                  NaN              N/A
# 3839           1.0                  3.0                5
# 3840           4.0                  5.0                5
#
#      Inflight Entertainment Value For Money Recommended
# 0                         1               1       False
# 1                      None               5       False
# 2                      None               3       False
# 3                      None               3       False
# 4                         1               1       False
# ...                     ...             ...         ...
# 3836                      4               3       False
# 3837                      0               3        True
# 3838                    N/A             N/A        None
# 3839                      0               1       False
# 3840                      2               2       False
#
# [3841 rows x 12 columns]

# %%
air_framce_reviews_df.insert(0, 'Airlines', 'air_france')
emirates_reviews_df.insert(0, 'Airlines', 'emirates')
qatar_airways_reviews_df.insert(0, 'Airlines', 'qatar_airways')
qantas_airways_reviews_df.insert(0, 'Airlines', 'qantas_airways')
singapore_airlines_reviews_df.insert(0, 'Airlines', 'singapore_airlines')

# %%
air_framce_reviews_df
# Out:
#         Airlines               Name Location Date Published  \
# 0     air_france             J Tung     2024     2024-08-06
# 1     air_france            N Reddy     2024     2024-08-05
# 2     air_france            S Baine     2024     2024-08-05
# 3     air_france  Ahmed Ahmed-Yahia     2024     2024-08-04
# 4     air_france        Chloe Davis     2024     2024-08-03
# ...          ...                ...      ...            ...
# 1373  air_france            T Price     2013     2013-06-19
# 1374  air_france           H Dalton     2013     2013-06-16
# 1375  air_france          F Francis     2013     2013-06-16
# 1376  air_france             Y Fall     2013     2013-06-12
# 1377  air_france         Nico Roets     2013     2013-06-09
#
#                                            Text Content       Seat Type  \
# 0     Not Verified | First time flying the newly ren...  Boeing 777-300
# 1     ✅ Trip Verified | I had a very disappointing e...    Solo Leisure
# 2     ✅ Trip Verified |   Only at first everything w...  Family Leisure
# 3     Not Verified | My son Ryan Ahmed-Yahia and I c...        A350-900
# 4     Not Verified |   Air France made an error when...  Family Leisure
# ...                                                 ...             ...
# 1373  BSL-CDG-ATH 28/5/13. Small ATR72 to CDG no han...   Economy Class
# 1374  2 June 2013 Johannesburg to Paris CDG AF 995. ...  Business Class
# 1375  CDG-JFK. AF-006 2013-05-21. The airline offers...   Economy Class
# 1376  Seoul-Paris CDG 777-300ER. Friendly and attent...   Economy Class
# 1377  We had a connecting flight this morning from P...   Economy Class
#
#       Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 0              NaN                  NaN               NaN
# 1              NaN                  NaN               NaN
# 2              NaN                  NaN               NaN
# 3              NaN                  NaN               NaN
# 4              NaN                  NaN               NaN
# ...            ...                  ...               ...
# 1373           3.0                  2.0               3.0
# 1374           4.0                  1.0               2.0
# 1375           3.0                  3.0               5.0
# 1376           3.0                  4.0               4.0
# 1377           2.0                  1.0               1.0
#
#       Inflight Entertainment Ground Service Wifi & Connectivity  \
# 0                        NaN              4                   5
# 1                        2.0              1                   1
# 2                        1.0              1                   1
# 3                        NaN              3                   4
# 4                        5.0              5                   1
# ...                      ...            ...                 ...
# 1373                     1.0              1                None
# 1374                     2.0              1                None
# 1375                     3.0              4                None
# 1376                     5.0              4                None
# 1377                     2.0              1                None
#
#      Value For Money Recommended
# 0                  5       False
# 1                  1       False
# 2                  2       False
# 3                  2       False
# 4                  1       False
# ...              ...         ...
# 1373             N/A        None
# 1374             N/A        None
# 1375             N/A        None
# 1376             N/A        None
# 1377             N/A        None
#
# [1378 rows x 14 columns]

# %%
airlines_review = pd.concat([
    british_airways_reviews_df,
    air_framce_reviews_df,
    emirates_reviews_df,
    qatar_airways_reviews_df,
    qantas_airways_reviews_df,
    singapore_airlines_reviews_df
], axis=0, ignore_index=True)

# %%
airlines_review.sample(10)
# Out:
#                  Airlines              Name Location Date Published  \
# 5805             emirates        T Neyrinck     2019     2019-05-31
# 1205      british_airways        C Hoffmann     2018     2018-10-23
# 3077      british_airways  Thomas Varughese     2015     2015-06-07
# 6625             emirates           P Evans     2016     2016-05-27
# 13119  singapore_airlines           S Siauw     2015     2015-10-20
# 1701      british_airways       Neil Baines     2017     2017-07-06
# 10599      qantas_airways       Simon Allan     2019     2019-08-06
# 557       british_airways    Haydn Robinson     2022     2022-04-04
# 9975        qatar_airways           M Hasan     2014     2014-01-22
# 11591      qantas_airways        John Smith     2014     2014-12-04
#
#                                             Text Content  \
# 5805   Not Verified |  Emirates business class offers...
# 1205   ✅ Trip Verified |  London to Munich. The groun...
# 3077   I had this terrible experience of traveling Br...
# 6625   Expecting a great deal based on other reviews ...
# 13119  Singapore to Tokyo Narita. I'm a Krisflyer gol...
# 1701   ✅ Verified Review |  London Heathrow to Larnac...
# 10599  ✅ Trip Verified |  Sydney to Perth. Caveat emp...
# 557    Not Verified |  The worst budget airline I’ve ...
# 9975   I used Qatar for the first time in January 201...
# 11591  Flew on QF1/QF2 flight from London to Sydney r...
#
#                    Seat Type  Seat Comfort  Cabin Staff Service  \
# 5805   Boeing 777-300 / A380           NaN                  NaN
# 1205                    A321           NaN                  NaN
# 3077           Economy Class           1.0                  4.0
# 6625          Family Leisure           NaN                  NaN
# 13119       Boeing 777-300ER           NaN                  NaN
# 1701              Boeing 767           NaN                  NaN
# 10599               Business           NaN                  NaN
# 557                 Business           NaN                  NaN
# 9975          Business Class           5.0                  5.0
# 11591         Business Class           3.0                  2.0
#
#       Food & Beverages Inflight Entertainment Value For Money Recommended  \
# 5805               NaN                    NaN               1       False
# 1205              None                   None               2       False
# 3077                 1                      2               1       False
# 6625               NaN                    3.0               4       False
# 13119              NaN                    NaN               3       False
# 1701              None                   None               2       False
# 10599              NaN                      1               3       False
# 557               None                      1               1       False
# 9975               5.0                    5.0             N/A        None
# 11591              1.0                      5             N/A        None
#
#       Ground Service Wifi & Connectivity
# 5805             4.0                   3
# 1205             NaN                 NaN
# 3077             NaN                 NaN
# 6625             1.0                   3
# 13119              5                   3
# 1701             NaN                 NaN
# 10599              4                   3
# 557              NaN                 NaN
# 9975             4.0                None
# 11591              4                None

# %%
airlines_review.shape
# Out:
# (13590, 14)

# %%
airlines_review.to_csv('airlines_review.csv', index=False)
